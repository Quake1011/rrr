# %%
import pandas as pd      #подключение модуля pandas
import matplotlib.pyplot as plt
import sqlite3      #подключение модуля для работы с локальными БД sqlite
con = sqlite3.connect("data.sqlite")      #подключаемся к локальной базе 
df = pd.read_sql_query("SELECT * FROM lvl_base ORDER BY value DESC", con)      #выполнение запроса
df
# Out:
#                      steam    value rank  kills deaths  shoots   hits  \
# 0      STEAM_1:0:561428281  4900195   15  64332  39797  334060  93893
# 1      STEAM_1:0:456079466  4750019   15  51575  29217  281404  85706
# 2      STEAM_1:1:578706388  4454440   15  39663  41564  413777  71383
# 3      STEAM_1:1:553021064  4248150   15  55275  24794  258892  86447
# 4      STEAM_1:0:197554056  4068757   15  25074   4682   48143  29974
# ...                    ...      ...  ...    ...    ...     ...    ...
# 47200   STEAM_1:1:98942594        0    1      0      0       0      0
# 47201   STEAM_1:1:99394709        0    1      0      0       0      0
# 47202   STEAM_1:1:99468685        0    1      0      0       0      0
# 47203   STEAM_1:1:99521231        0    1      0      0       0      0
# 47204   STEAM_1:1:99831784        0    1      0      0       0      0
#
#       headshots assists round_win round_lose playtime  lastconnect  lastrank  \
# ...

# %%
df.plot(x="ID",y="value",kind="scatter",xlim=(0,50000),ylim=(0,5000000))      #вывод разброса данных

# %%
df.plot(x="ID",y="value",kind="line",xlim=(0,50000),ylim=(0,5000000))      #вывод разброса данных

# %%
df.plot(x="ID",y="value",kind="box")      #вывод разброса данных

# %%
df.plot(x="ID",y="value",kind="area")      #вывод разброса данных
